# %%
# !aws login
# Out:
# Attempting to open your default browser.
# If the browser does not open, open the following URL:
#
# https://us-east-1.signin.aws.amazon.com/v1/authorize?response_type=code&client_id=arn%3Aaws%3Asignin%3A%3A%3Adevtools%2Fsame-device&state=2d2387cb-b253-45af-a508-8fd58780a877&code_challenge_method=SHA-256&scope=openid&redirect_uri=http%3A%2F%2F127.0.0.1%3A60441%2Foauth%2Fcallback&code_challenge=VXqMAVSV4iEQ028uGtLLBFKY9YNlyndDWPM-vfMjypc
#
# Updated profile default to use arn:aws:sts::549787090008:assumed-role/AWSReservedSSO_mse-tl-dataeng300-EMR_da0cc2e9e5742c69/phf6371 credentials.

# %%
import os
import time
import argparse
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

import requests
import pandas as pd
import boto3

import boto3
import requests
import zipfile
import tempfile
from pathlib import Path
from botocore.exceptions import ClientError

# %%
session = boto3.Session(region_name='us-east-1')
s3 = session.client('s3')

BUCKET = 'bustrust'
PREFIX = 'datasets'

# Defining S3 keys
zip_key = f'{PREFIX}/ml-1.zip'
extract_prefix = f'{PREFIX}/ml-1m/'

# %%
CHICAGO_TZ = ZoneInfo("America/Chicago")


def chunk_list(xs, n=10):
    return [xs[i : i + n] for i in range(0, len(xs), n)]


def get_routes(session: requests.Session, api_key: str):
    url = f"https://www.ctabustracker.com/bustime/api/v3/getroutes?key={api_key}&format=json"
    r = session.get(url, timeout=30)
    r.raise_for_status()
    data = r.json()

    routes = data.get("bustime-response", {}).get("routes", [])
    if not routes:
        err = data.get("bustime-response", {}).get("error", [])
        raise ValueError(f"No routes returned. Error: {err}")

    return [rt["rt"] for rt in routes if "rt" in rt]


def get_api(session: requests.Session, url: str):
    r = session.get(url, timeout=30)
    if r.ok:
        return r.json()
    raise ValueError(f"API request failed (status={r.status_code})")


def append_vehicles_to_csv(data, outfile: str, pulled_at: str, rt_chunk: str) -> int:
    vehicles = data.get("bustime-response", {}).get("vehicle", None)
    if not vehicles:
        return 0

    df = pd.DataFrame(vehicles)
    df["pulled_at"] = pulled_at
    df["rt_chunk"] = rt_chunk

    file_exists = os.path.exists(outfile)
    df.to_csv(outfile, mode="a", header=not file_exists, index=False)
    return len(df)


def _current_outfile(out_dir: str) -> str:
    return os.path.join(out_dir, "bus_data_current_chicago.csv")


def _s3_key_for_chunk(chunk_start_dt: datetime, chunk_hours: float) -> str:
    chunk_end_dt = chunk_start_dt + timedelta(hours=chunk_hours)
    start_stamp = chunk_start_dt.strftime("%Y-%m-%d_%H-%M-%S")
    end_stamp = chunk_end_dt.strftime("%Y-%m-%d_%H-%M-%S")
    filename = f"bus_data_{start_stamp}_to_{end_stamp}_chicago.csv"
    return os.path.join("data_collection", filename)


def _upload_file_to_s3_with_key(s3, bucket_name: str, local_path: str, s3_key: str) -> str:
    s3.upload_file(local_path, bucket_name, s3_key)
    return s3_key


def main(
    api_key: str,
    runtime_seconds: int,
    per_chunk_sleep: int = 5,
    per_sweep_sleep: int = 30,
    out_dir: str = "data",
    chunk_hours: float = 6.0,
    s3_bucket: str = "bustrust",
    no_s3_upload: bool = False,
):
    if chunk_hours <= 0:
        raise ValueError("chunk_hours must be > 0 (e.g., 6).")
    if runtime_seconds <= 0:
        raise ValueError("runtime_seconds must be > 0.")

    os.makedirs(out_dir, exist_ok=True)

    session = requests.Session()
    routes = get_routes(session, api_key)
    route_chunks = chunk_list(routes, n=10)

    start_ts = time.time()
    end_ts = start_ts + runtime_seconds

    chunk_seconds = int(chunk_hours * 3600)

    # Chunk schedule (fixed relative to start)
    chunk_start_ts = start_ts
    chunk_start_dt = datetime.now(CHICAGO_TZ)  # used for S3 filenames
    next_rollover_ts = chunk_start_ts + chunk_seconds

    # Single local file
    outfile = _current_outfile(out_dir)

    s3_client = None
    if not no_s3_upload:
        s3_client = boto3.client("s3")

    print(f"Found {len(routes)} routes -> {len(route_chunks)} route-chunks")
    print(f"Local output (single file): {os.path.abspath(outfile)}")
    print(f"Chunk: {chunk_hours} hours ({chunk_seconds} seconds)")
    print(f"Sleep: per_chunk={per_chunk_sleep}s | per_sweep={per_sweep_sleep}s | runtime={runtime_seconds}s")
    print("S3 upload:", "DISABLED" if no_s3_upload else f"ENABLED -> s3://{s3_bucket}/data_collection/")
    print("Upload policy: ONLY at chunk boundary; delete local file after successful upload.")
    print("If upload fails: keep writing into the SAME local file; do NOT advance chunk window.")

    sweep_num = 0
    call_num = 0
    total_rows = 0

    def rollover_if_needed():
        """
        The ONLY place an upload can happen.
        If we crossed the chunk boundary, we upload the single local file to a timestamped S3 key.
        - On success: delete local file and advance chunk window by exactly one chunk.
        - On failure: keep local file; do NOT advance the chunk window (prevents mixing windows).
        """
        nonlocal chunk_start_ts, chunk_start_dt, next_rollover_ts

        now_ts = time.time()
        if now_ts < next_rollover_ts:
            return

        # If there's nothing written yet, still advance the window (optional behavior).
        # Here, we only try to upload if the file exists and has non-zero size.
        has_data = os.path.exists(outfile) and os.path.getsize(outfile) > 0

        if not no_s3_upload and s3_client is not None and has_data:
            s3_key = _s3_key_for_chunk(chunk_start_dt, chunk_hours)
            try:
                _upload_file_to_s3_with_key(s3_client, s3_bucket, outfile, s3_key)
                print(f"  [S3] uploaded -> s3://{s3_bucket}/{s3_key}")

                # Delete local file so we never keep multiple files.
                os.remove(outfile)
                print(f"  [LOCAL] deleted -> {outfile}")

            except Exception as e:
                print(f"  [S3] upload ERROR (continuing with same local file): {e}")
                # Do NOT advance chunk window if upload failed.
                return

        # Advance chunk window deterministically.
        # If we've fallen behind multiple boundaries, advance one at a time.
        # (We don't "catch up" multiple windows because we keep a single file.)
        chunk_start_ts = next_rollover_ts
        chunk_start_dt = chunk_start_dt + timedelta(hours=chunk_hours)
        next_rollover_ts = chunk_start_ts + chunk_seconds
        print(f"--- Rolled over chunk window. Continuing in same local file: {os.path.basename(outfile)}")

    while time.time() < end_ts:
        rollover_if_needed()

        sweep_num += 1
        now_label = datetime.now(CHICAGO_TZ).strftime("%Y-%m-%d %H:%M:%S %Z")
        print(f"--- Sweep {sweep_num} @ {now_label} ---")

        for i, chunk in enumerate(route_chunks):
            if time.time() >= end_ts:
                break

            rollover_if_needed()

            rt_param = ",".join(chunk)
            url = (
                "https://www.ctabustracker.com/bustime/api/v3/getvehicles"
                f"?key={api_key}&rt={rt_param}&format=json"
            )
            pulled_at = datetime.now(CHICAGO_TZ).strftime("%Y-%m-%d %H:%M:%S %Z")

            try:
                data = get_api(session, url)
                n_rows = append_vehicles_to_csv(data, outfile, pulled_at=pulled_at, rt_chunk=rt_param)
                call_num += 1
                total_rows += n_rows
                print(
                    f"[Call {call_num}] routeset {i+1}/{len(route_chunks)}: +{n_rows} rows "
                    f"(total {total_rows}) -> {os.path.basename(outfile)}"
                )
            except Exception as e:
                call_num += 1
                print(f"[Call {call_num}] routeset {i+1}/{len(route_chunks)} ERROR: {e}")

            if time.time() < end_ts:
                time.sleep(min(per_chunk_sleep, max(0, end_ts - time.time())))

        if time.time() < end_ts:
            sleep_now = min(per_sweep_sleep, max(0, end_ts - time.time()))
            print(f"--- Sweep {sweep_num} complete. Sleeping {sleep_now:.0f}s ---")
            time.sleep(sleep_now)

    # ALWAYS upload whatever remains ONCE at shutdown (unless S3 disabled)
    if (not no_s3_upload) and (s3_client is not None):
        if os.path.exists(outfile) and os.path.getsize(outfile) > 0:
            s3_key = _s3_key_for_chunk(chunk_start_dt, chunk_hours)
            try:
                _upload_file_to_s3_with_key(s3_client, s3_bucket, outfile, s3_key)
                print(f"  [S3] uploaded (exit) -> s3://{s3_bucket}/{s3_key}")
                os.remove(outfile)
                print(f"  [LOCAL] deleted (exit) -> {outfile}")
            except Exception as e:
                print(f"  [S3] upload ERROR on exit (file kept): {e}")

    print(f"\nDone. Sweeps: {sweep_num}, calls: {call_num}, total rows written: {total_rows}")

# %%
main(
        api_key='NPeYcrgS6Pt432G5F64u8jgQD',
        runtime_seconds=39600,
        per_chunk_sleep=5,
        per_sweep_sleep=30,
        out_dir="data/test3",
        chunk_hours=6,
        s3_bucket='bustrust',
        no_s3_upload=False,
    )
# Out:
# Found 124 routes -> 13 route-chunks
# Local output (single file): /Users/pedrohenriquefarina/CTABusTrust/CTABusTrust/data/test3/bus_data_current_chicago.csv
# Chunk: 6 hours (21600 seconds)
# Sleep: per_chunk=5s | per_sweep=30s | runtime=39600s
# S3 upload: ENABLED -> s3://bustrust/data_collection/
# Upload policy: ONLY at chunk boundary; delete local file after successful upload.
# If upload fails: keep writing into the SAME local file; do NOT advance chunk window.
# --- Sweep 1 @ 2026-02-19 23:41:14 CST ---
# [Call 1] routeset 1/13: +34 rows (total 34) -> bus_data_current_chicago.csv
# [Call 2] routeset 2/13: +27 rows (total 61) -> bus_data_current_chicago.csv
# [Call 3] routeset 3/13: +29 rows (total 90) -> bus_data_current_chicago.csv
# [Call 4] routeset 4/13: +18 rows (total 108) -> bus_data_current_chicago.csv
# [Call 5] routeset 5/13: +27 rows (total 135) -> bus_data_current_chicago.csv
# [Call 6] routeset 6/13: +19 rows (total 154) -> bus_data_current_chicago.csv
# [Call 7] routeset 7/13: +39 rows (total 193) -> bus_data_current_chicago.csv
# [Call 8] routeset 8/13: +43 rows (total 236) -> bus_data_current_chicago.csv
# [Call 9] routeset 9/13: +17 rows (total 253) -> bus_data_current_chicago.csv
# [Call 10] routeset 10/13: +3 rows (total 256) -> bus_data_current_chicago.csv
# [Call 11] routeset 11/13: +6 rows (total 262) -> bus_data_current_chicago.csv
# [Call 12] routeset 12/13: +13 rows (total 275) -> bus_data_current_chicago.csv
# [Call 13] routeset 13/13: +0 rows (total 275) -> bus_data_current_chicago.csv
# --- Sweep 1 complete. Sleeping 30s ---
# --- Sweep 2 @ 2026-02-19 23:42:50 CST ---
# [Call 14] routeset 1/13: +33 rows (total 308) -> bus_data_current_chicago.csv
# [Call 15] routeset 2/13: +27 rows (total 335) -> bus_data_current_chicago.csv
# [Call 16] routeset 3/13: +27 rows (total 362) -> bus_data_current_chicago.csv
# [Call 17] routeset 4/13: +19 rows (total 381) -> bus_data_current_chicago.csv
# [Call 18] routeset 5/13: +28 rows (total 409) -> bus_data_current_chicago.csv
# [Call 19] routeset 6/13: +17 rows (total 426) -> bus_data_current_chicago.csv
# [Call 20] routeset 7/13: +38 rows (total 464) -> bus_data_current_chicago.csv
# [Call 21] routeset 8/13: +42 rows (total 506) -> bus_data_current_chicago.csv
# [Call 22] routeset 9/13: +17 rows (total 523) -> bus_data_current_chicago.csv
# [Call 23] routeset 10/13: +3 rows (total 526) -> bus_data_current_chicago.csv
# [Call 24] routeset 11/13: +6 rows (total 532) -> bus_data_current_chicago.csv
# [Call 25] routeset 12/13: +12 rows (total 544) -> bus_data_current_chicago.csv
# [Call 26] routeset 13/13: +0 rows (total 544) -> bus_data_current_chicago.csv
# --- Sweep 2 complete. Sleeping 30s ---
# --- Sweep 3 @ 2026-02-19 23:44:26 CST ---
# [Call 27] routeset 1/13: +33 rows (total 577) -> bus_data_current_chicago.csv
# [Call 28] routeset 2/13: +28 rows (total 605) -> bus_data_current_chicago.csv
# [Call 29] routeset 3/13: +27 rows (total 632) -> bus_data_current_chicago.csv
# [Call 30] routeset 4/13: +19 rows (total 651) -> bus_data_current_chicago.csv
# [Call 31] routeset 5/13: +28 rows (total 679) -> bus_data_current_chicago.csv
# [Call 32] routeset 6/13: +18 rows (total 697) -> bus_data_current_chicago.csv
# [Call 33] routeset 7/13: +37 rows (total 734) -> bus_data_current_chicago.csv
# [Call 34] routeset 8/13: +41 rows (total 775) -> bus_data_current_chicago.csv
# [Call 35] routeset 9/13: +16 rows (total 791) -> bus_data_current_chicago.csv
# [Call 36] routeset 10/13: +3 rows (total 794) -> bus_data_current_chicago.csv
# [Call 37] routeset 11/13: +5 rows (total 799) -> bus_data_current_chicago.csv
# [Call 38] routeset 12/13: +12 rows (total 811) -> bus_data_current_chicago.csv
# [Call 39] routeset 13/13: +0 rows (total 811) -> bus_data_current_chicago.csv
# --- Sweep 3 complete. Sleeping 30s ---
# --- Sweep 4 @ 2026-02-19 23:46:02 CST ---
# [Call 40] routeset 1/13: +32 rows (total 843) -> bus_data_current_chicago.csv
# [Call 41] routeset 2/13: +28 rows (total 871) -> bus_data_current_chicago.csv
# [Call 42] routeset 3/13: +26 rows (total 897) -> bus_data_current_chicago.csv
# [Call 43] routeset 4/13: +20 rows (total 917) -> bus_data_current_chicago.csv
# [Call 44] routeset 5/13: +29 rows (total 946) -> bus_data_current_chicago.csv
# [Call 45] routeset 6/13: +17 rows (total 963) -> bus_data_current_chicago.csv
# [Call 46] routeset 7/13: +36 rows (total 999) -> bus_data_current_chicago.csv
# [Call 47] routeset 8/13: +41 rows (total 1040) -> bus_data_current_chicago.csv
# [Call 48] routeset 9/13: +16 rows (total 1056) -> bus_data_current_chicago.csv
# [Call 49] routeset 10/13: +3 rows (total 1059) -> bus_data_current_chicago.csv
# [Call 50] routeset 11/13: +5 rows (total 1064) -> bus_data_current_chicago.csv
# [Call 51] routeset 12/13: +12 rows (total 1076) -> bus_data_current_chicago.csv
# [Call 52] routeset 13/13: +0 rows (total 1076) -> bus_data_current_chicago.csv
# --- Sweep 4 complete. Sleeping 30s ---
# --- Sweep 5 @ 2026-02-19 23:47:38 CST ---
# [Call 53] routeset 1/13: +33 rows (total 1109) -> bus_data_current_chicago.csv
# [Call 54] routeset 2/13: +29 rows (total 1138) -> bus_data_current_chicago.csv
# [Call 55] routeset 3/13: +27 rows (total 1165) -> bus_data_current_chicago.csv
# [Call 56] routeset 4/13: +21 rows (total 1186) -> bus_data_current_chicago.csv
# [Call 57] routeset 5/13: +28 rows (total 1214) -> bus_data_current_chicago.csv
# [Call 58] routeset 6/13: +18 rows (total 1232) -> bus_data_current_chicago.csv
# [Call 59] routeset 7/13: +37 rows (total 1269) -> bus_data_current_chicago.csv
# [Call 60] routeset 8/13: +41 rows (total 1310) -> bus_data_current_chicago.csv
# [Call 61] routeset 9/13: +15 rows (total 1325) -> bus_data_current_chicago.csv
# [Call 62] routeset 10/13: +3 rows (total 1328) -> bus_data_current_chicago.csv
# [Call 63] routeset 11/13: +4 rows (total 1332) -> bus_data_current_chicago.csv
# [Call 64] routeset 12/13: +12 rows (total 1344) -> bus_data_current_chicago.csv
# [Call 65] routeset 13/13: +0 rows (total 1344) -> bus_data_current_chicago.csv
# --- Sweep 5 complete. Sleeping 30s ---
# --- Sweep 6 @ 2026-02-19 23:49:14 CST ---
# [Call 66] routeset 1/13: +33 rows (total 1377) -> bus_data_current_chicago.csv
# [Call 67] routeset 2/13: +29 rows (total 1406) -> bus_data_current_chicago.csv
# [Call 68] routeset 3/13: +27 rows (total 1433) -> bus_data_current_chicago.csv
# [Call 69] routeset 4/13: +21 rows (total 1454) -> bus_data_current_chicago.csv
# [Call 70] routeset 5/13: +28 rows (total 1482) -> bus_data_current_chicago.csv
# [Call 71] routeset 6/13: +19 rows (total 1501) -> bus_data_current_chicago.csv
# [Call 72] routeset 7/13: +36 rows (total 1537) -> bus_data_current_chicago.csv
# [Call 73] routeset 8/13: +41 rows (total 1578) -> bus_data_current_chicago.csv
# [Call 74] routeset 9/13: +16 rows (total 1594) -> bus_data_current_chicago.csv
# [Call 75] routeset 10/13: +3 rows (total 1597) -> bus_data_current_chicago.csv
# [Call 76] routeset 11/13: +4 rows (total 1601) -> bus_data_current_chicago.csv
# [Call 77] routeset 12/13: +12 rows (total 1613) -> bus_data_current_chicago.csv
# [Call 78] routeset 13/13: +0 rows (total 1613) -> bus_data_current_chicago.csv
# --- Sweep 6 complete. Sleeping 30s ---
# --- Sweep 7 @ 2026-02-19 23:50:49 CST ---
# [Call 79] routeset 1/13: +32 rows (total 1645) -> bus_data_current_chicago.csv
# [Call 80] routeset 2/13: +28 rows (total 1673) -> bus_data_current_chicago.csv
# [Call 81] routeset 3/13: +26 rows (total 1699) -> bus_data_current_chicago.csv
# [Call 82] routeset 4/13: +19 rows (total 1718) -> bus_data_current_chicago.csv
# [Call 83] routeset 5/13: +27 rows (total 1745) -> bus_data_current_chicago.csv
# [Call 84] routeset 6/13: +17 rows (total 1762) -> bus_data_current_chicago.csv
# [Call 85] routeset 7/13: +35 rows (total 1797) -> bus_data_current_chicago.csv
# [Call 86] routeset 8/13: +41 rows (total 1838) -> bus_data_current_chicago.csv
# [Call 87] routeset 9/13: +15 rows (total 1853) -> bus_data_current_chicago.csv
# [Call 88] routeset 10/13: +3 rows (total 1856) -> bus_data_current_chicago.csv
# [Call 89] routeset 11/13: +4 rows (total 1860) -> bus_data_current_chicago.csv
# [Call 90] routeset 12/13: +11 rows (total 1871) -> bus_data_current_chicago.csv
# [Call 91] routeset 13/13: +0 rows (total 1871) -> bus_data_current_chicago.csv
# --- Sweep 7 complete. Sleeping 30s ---
# --- Sweep 8 @ 2026-02-19 23:52:25 CST ---
# [Call 92] routeset 1/13: +31 rows (total 1902) -> bus_data_current_chicago.csv
# [Call 93] routeset 2/13: +29 rows (total 1931) -> bus_data_current_chicago.csv
# [Call 94] routeset 3/13: +26 rows (total 1957) -> bus_data_current_chicago.csv
# [Call 95] routeset 4/13: +18 rows (total 1975) -> bus_data_current_chicago.csv
# [Call 96] routeset 5/13: +25 rows (total 2000) -> bus_data_current_chicago.csv
# [Call 97] routeset 6/13: +17 rows (total 2017) -> bus_data_current_chicago.csv
# [Call 98] routeset 7/13: +35 rows (total 2052) -> bus_data_current_chicago.csv
# [Call 99] routeset 8/13: +41 rows (total 2093) -> bus_data_current_chicago.csv
# [Call 100] routeset 9/13: +15 rows (total 2108) -> bus_data_current_chicago.csv
# [Call 101] routeset 10/13: +3 rows (total 2111) -> bus_data_current_chicago.csv
# [Call 102] routeset 11/13: +3 rows (total 2114) -> bus_data_current_chicago.csv
# [Call 103] routeset 12/13: +11 rows (total 2125) -> bus_data_current_chicago.csv
# [Call 104] routeset 13/13: +0 rows (total 2125) -> bus_data_current_chicago.csv
# --- Sweep 8 complete. Sleeping 30s ---
# --- Sweep 9 @ 2026-02-19 23:54:01 CST ---
# [Call 105] routeset 1/13: +31 rows (total 2156) -> bus_data_current_chicago.csv
# [Call 106] routeset 2/13: +29 rows (total 2185) -> bus_data_current_chicago.csv
# [Call 107] routeset 3/13: +25 rows (total 2210) -> bus_data_current_chicago.csv
# [Call 108] routeset 4/13: +18 rows (total 2228) -> bus_data_current_chicago.csv
# [Call 109] routeset 5/13: +25 rows (total 2253) -> bus_data_current_chicago.csv
# [Call 110] routeset 6/13: +18 rows (total 2271) -> bus_data_current_chicago.csv
# [Call 111] routeset 7/13: +34 rows (total 2305) -> bus_data_current_chicago.csv
# [Call 112] routeset 8/13: +41 rows (total 2346) -> bus_data_current_chicago.csv
# [Call 113] routeset 9/13: +14 rows (total 2360) -> bus_data_current_chicago.csv
# [Call 114] routeset 10/13: +3 rows (total 2363) -> bus_data_current_chicago.csv
# [Call 115] routeset 11/13: +4 rows (total 2367) -> bus_data_current_chicago.csv
# [Call 116] routeset 12/13: +11 rows (total 2378) -> bus_data_current_chicago.csv
# [Call 117] routeset 13/13: +0 rows (total 2378) -> bus_data_current_chicago.csv
# --- Sweep 9 complete. Sleeping 30s ---
# --- Sweep 10 @ 2026-02-19 23:55:37 CST ---
# [Call 118] routeset 1/13: +32 rows (total 2410) -> bus_data_current_chicago.csv
# [Call 119] routeset 2/13: +27 rows (total 2437) -> bus_data_current_chicago.csv
# [Call 120] routeset 3/13: +26 rows (total 2463) -> bus_data_current_chicago.csv
# [Call 121] routeset 4/13: +18 rows (total 2481) -> bus_data_current_chicago.csv
# [Call 122] routeset 5/13: +24 rows (total 2505) -> bus_data_current_chicago.csv
# [Call 123] routeset 6/13: +16 rows (total 2521) -> bus_data_current_chicago.csv
# [Call 124] routeset 7/13: +34 rows (total 2555) -> bus_data_current_chicago.csv
# [Call 125] routeset 8/13: +41 rows (total 2596) -> bus_data_current_chicago.csv
# [Call 126] routeset 9/13: +13 rows (total 2609) -> bus_data_current_chicago.csv
# [Call 127] routeset 10/13: +3 rows (total 2612) -> bus_data_current_chicago.csv
# [Call 128] routeset 11/13: +4 rows (total 2616) -> bus_data_current_chicago.csv
# [Call 129] routeset 12/13: +11 rows (total 2627) -> bus_data_current_chicago.csv
# [Call 130] routeset 13/13: +0 rows (total 2627) -> bus_data_current_chicago.csv
# --- Sweep 10 complete. Sleeping 30s ---
# --- Sweep 11 @ 2026-02-19 23:57:13 CST ---
# [Call 131] routeset 1/13: +32 rows (total 2659) -> bus_data_current_chicago.csv
# [Call 132] routeset 2/13: +26 rows (total 2685) -> bus_data_current_chicago.csv
# [Call 133] routeset 3/13: +25 rows (total 2710) -> bus_data_current_chicago.csv
# [Call 134] routeset 4/13: +17 rows (total 2727) -> bus_data_current_chicago.csv
# [Call 135] routeset 5/13: +24 rows (total 2751) -> bus_data_current_chicago.csv
# [Call 136] routeset 6/13: +15 rows (total 2766) -> bus_data_current_chicago.csv
# [Call 137] routeset 7/13: +34 rows (total 2800) -> bus_data_current_chicago.csv
# [Call 138] routeset 8/13: +41 rows (total 2841) -> bus_data_current_chicago.csv
# [Call 139] routeset 9/13: +12 rows (total 2853) -> bus_data_current_chicago.csv
# [Call 140] routeset 10/13: +3 rows (total 2856) -> bus_data_current_chicago.csv
# [Call 141] routeset 11/13: +4 rows (total 2860) -> bus_data_current_chicago.csv
# [Call 142] routeset 12/13: +11 rows (total 2871) -> bus_data_current_chicago.csv
# [Call 143] routeset 13/13: +0 rows (total 2871) -> bus_data_current_chicago.csv
# --- Sweep 11 complete. Sleeping 30s ---
# --- Sweep 12 @ 2026-02-19 23:58:49 CST ---
# [Call 144] routeset 1/13: +31 rows (total 2902) -> bus_data_current_chicago.csv
# [Call 145] routeset 2/13: +27 rows (total 2929) -> bus_data_current_chicago.csv
# [Call 146] routeset 3/13: +24 rows (total 2953) -> bus_data_current_chicago.csv
# [Call 147] routeset 4/13: +17 rows (total 2970) -> bus_data_current_chicago.csv
# [Call 148] routeset 5/13: +24 rows (total 2994) -> bus_data_current_chicago.csv
# [Call 149] routeset 6/13: +14 rows (total 3008) -> bus_data_current_chicago.csv
# [Call 150] routeset 7/13: +34 rows (total 3042) -> bus_data_current_chicago.csv
# [Call 151] routeset 8/13: +39 rows (total 3081) -> bus_data_current_chicago.csv
# [Call 152] routeset 9/13: +11 rows (total 3092) -> bus_data_current_chicago.csv
# [Call 153] routeset 10/13: +3 rows (total 3095) -> bus_data_current_chicago.csv
# [Call 154] routeset 11/13: +4 rows (total 3099) -> bus_data_current_chicago.csv
# [Call 155] routeset 12/13: +10 rows (total 3109) -> bus_data_current_chicago.csv
# [Call 156] routeset 13/13: +0 rows (total 3109) -> bus_data_current_chicago.csv
# --- Sweep 12 complete. Sleeping 30s ---
# --- Sweep 13 @ 2026-02-20 00:00:26 CST ---
# [Call 157] routeset 1/13: +32 rows (total 3141) -> bus_data_current_chicago.csv
# [Call 158] routeset 2/13: +27 rows (total 3168) -> bus_data_current_chicago.csv
# [Call 159] routeset 3/13: +24 rows (total 3192) -> bus_data_current_chicago.csv
# [Call 160] routeset 4/13: +18 rows (total 3210) -> bus_data_current_chicago.csv
# [Call 161] routeset 5/13: +24 rows (total 3234) -> bus_data_current_chicago.csv
# [Call 162] routeset 6/13: +15 rows (total 3249) -> bus_data_current_chicago.csv
# [Call 163] routeset 7/13: +34 rows (total 3283) -> bus_data_current_chicago.csv
# [Call 164] routeset 8/13: +39 rows (total 3322) -> bus_data_current_chicago.csv
# [Call 165] routeset 9/13: +11 rows (total 3333) -> bus_data_current_chicago.csv
# [Call 166] routeset 10/13: +3 rows (total 3336) -> bus_data_current_chicago.csv
# [Call 167] routeset 11/13: +3 rows (total 3339) -> bus_data_current_chicago.csv
# [Call 168] routeset 12/13: +9 rows (total 3348) -> bus_data_current_chicago.csv
# [Call 169] routeset 13/13: +0 rows (total 3348) -> bus_data_current_chicago.csv
# --- Sweep 13 complete. Sleeping 30s ---
# --- Sweep 14 @ 2026-02-20 00:02:01 CST ---
# [Call 170] routeset 1/13: +33 rows (total 3381) -> bus_data_current_chicago.csv
# [Call 171] routeset 2/13: +26 rows (total 3407) -> bus_data_current_chicago.csv
# [Call 172] routeset 3/13: +25 rows (total 3432) -> bus_data_current_chicago.csv
# [Call 173] routeset 4/13: +18 rows (total 3450) -> bus_data_current_chicago.csv
# [Call 174] routeset 5/13: +24 rows (total 3474) -> bus_data_current_chicago.csv
# [Call 175] routeset 6/13 ERROR: HTTPSConnectionPool(host='www.ctabustracker.com', port=443): Read timed out. (read timeout=30)
# [Call 176] routeset 7/13: +32 rows (total 3506) -> bus_data_current_chicago.csv
# [Call 177] routeset 8/13: +39 rows (total 3545) -> bus_data_current_chicago.csv
# [Call 178] routeset 9/13: +12 rows (total 3557) -> bus_data_current_chicago.csv
# [Call 179] routeset 10/13: +3 rows (total 3560) -> bus_data_current_chicago.csv
# [Call 180] routeset 11/13: +3 rows (total 3563) -> bus_data_current_chicago.csv
# [Call 181] routeset 12/13: +9 rows (total 3572) -> bus_data_current_chicago.csv
# [Call 182] routeset 13/13: +0 rows (total 3572) -> bus_data_current_chicago.csv
# --- Sweep 14 complete. Sleeping 30s ---
# --- Sweep 15 @ 2026-02-20 00:04:07 CST ---
# [Call 183] routeset 1/13: +32 rows (total 3604) -> bus_data_current_chicago.csv
# [Call 184] routeset 2/13: +26 rows (total 3630) -> bus_data_current_chicago.csv
# [Call 185] routeset 3/13: +24 rows (total 3654) -> bus_data_current_chicago.csv
# [Call 186] routeset 4/13: +17 rows (total 3671) -> bus_data_current_chicago.csv
# [Call 187] routeset 5/13: +25 rows (total 3696) -> bus_data_current_chicago.csv
# [Call 188] routeset 6/13: +14 rows (total 3710) -> bus_data_current_chicago.csv
# [Call 189] routeset 7/13: +31 rows (total 3741) -> bus_data_current_chicago.csv
# [Call 190] routeset 8/13: +39 rows (total 3780) -> bus_data_current_chicago.csv
# [Call 191] routeset 9/13: +11 rows (total 3791) -> bus_data_current_chicago.csv
# [Call 192] routeset 10/13: +3 rows (total 3794) -> bus_data_current_chicago.csv
# [Call 193] routeset 11/13: +3 rows (total 3797) -> bus_data_current_chicago.csv
# [Call 194] routeset 12/13: +9 rows (total 3806) -> bus_data_current_chicago.csv
# [Call 195] routeset 13/13: +0 rows (total 3806) -> bus_data_current_chicago.csv
# --- Sweep 15 complete. Sleeping 30s ---
# --- Sweep 16 @ 2026-02-20 00:05:43 CST ---
# [Call 196] routeset 1/13: +32 rows (total 3838) -> bus_data_current_chicago.csv
# [Call 197] routeset 2/13: +25 rows (total 3863) -> bus_data_current_chicago.csv
# [Call 198] routeset 3/13: +24 rows (total 3887) -> bus_data_current_chicago.csv
# [Call 199] routeset 4/13: +17 rows (total 3904) -> bus_data_current_chicago.csv
# [Call 200] routeset 5/13: +25 rows (total 3929) -> bus_data_current_chicago.csv
# [Call 201] routeset 6/13: +15 rows (total 3944) -> bus_data_current_chicago.csv
# [Call 202] routeset 7/13: +31 rows (total 3975) -> bus_data_current_chicago.csv
# [Call 203] routeset 8/13: +40 rows (total 4015) -> bus_data_current_chicago.csv
# [Call 204] routeset 9/13: +11 rows (total 4026) -> bus_data_current_chicago.csv
# [Call 205] routeset 10/13: +3 rows (total 4029) -> bus_data_current_chicago.csv
# [Call 206] routeset 11/13: +3 rows (total 4032) -> bus_data_current_chicago.csv
# [Call 207] routeset 12/13: +9 rows (total 4041) -> bus_data_current_chicago.csv
# [Call 208] routeset 13/13: +0 rows (total 4041) -> bus_data_current_chicago.csv
# --- Sweep 16 complete. Sleeping 30s ---
# --- Sweep 17 @ 2026-02-20 00:07:19 CST ---
# [Call 209] routeset 1/13: +31 rows (total 4072) -> bus_data_current_chicago.csv
# [Call 210] routeset 2/13: +25 rows (total 4097) -> bus_data_current_chicago.csv
# [Call 211] routeset 3/13: +24 rows (total 4121) -> bus_data_current_chicago.csv
# [Call 212] routeset 4/13: +17 rows (total 4138) -> bus_data_current_chicago.csv
# [Call 213] routeset 5/13: +25 rows (total 4163) -> bus_data_current_chicago.csv
# [Call 214] routeset 6/13: +15 rows (total 4178) -> bus_data_current_chicago.csv
# [Call 215] routeset 7/13: +32 rows (total 4210) -> bus_data_current_chicago.csv
# [Call 216] routeset 8/13: +37 rows (total 4247) -> bus_data_current_chicago.csv
# [Call 217] routeset 9/13: +11 rows (total 4258) -> bus_data_current_chicago.csv
# [Call 218] routeset 10/13: +3 rows (total 4261) -> bus_data_current_chicago.csv
# [Call 219] routeset 11/13: +3 rows (total 4264) -> bus_data_current_chicago.csv
# [Call 220] routeset 12/13: +10 rows (total 4274) -> bus_data_current_chicago.csv
# [Call 221] routeset 13/13: +0 rows (total 4274) -> bus_data_current_chicago.csv
# --- Sweep 17 complete. Sleeping 30s ---
# --- Sweep 18 @ 2026-02-20 00:08:55 CST ---
# [Call 222] routeset 1/13: +30 rows (total 4304) -> bus_data_current_chicago.csv
# [Call 223] routeset 2/13: +25 rows (total 4329) -> bus_data_current_chicago.csv
# [Call 224] routeset 3/13: +24 rows (total 4353) -> bus_data_current_chicago.csv
# [Call 225] routeset 4/13: +17 rows (total 4370) -> bus_data_current_chicago.csv
# [Call 226] routeset 5/13: +24 rows (total 4394) -> bus_data_current_chicago.csv
# [Call 227] routeset 6/13: +15 rows (total 4409) -> bus_data_current_chicago.csv
# [Call 228] routeset 7/13: +32 rows (total 4441) -> bus_data_current_chicago.csv
# [Call 229] routeset 8/13: +37 rows (total 4478) -> bus_data_current_chicago.csv
# [Call 230] routeset 9/13: +11 rows (total 4489) -> bus_data_current_chicago.csv
# [Call 231] routeset 10/13: +3 rows (total 4492) -> bus_data_current_chicago.csv
# [Call 232] routeset 11/13: +3 rows (total 4495) -> bus_data_current_chicago.csv
# [Call 233] routeset 12/13: +10 rows (total 4505) -> bus_data_current_chicago.csv
# [Call 234] routeset 13/13: +0 rows (total 4505) -> bus_data_current_chicago.csv
# --- Sweep 18 complete. Sleeping 30s ---
# --- Sweep 19 @ 2026-02-20 00:10:31 CST ---
# [Call 235] routeset 1/13: +30 rows (total 4535) -> bus_data_current_chicago.csv
# [Call 236] routeset 2/13: +25 rows (total 4560) -> bus_data_current_chicago.csv
# [Call 237] routeset 3/13: +23 rows (total 4583) -> bus_data_current_chicago.csv
# [Call 238] routeset 4/13: +17 rows (total 4600) -> bus_data_current_chicago.csv
# [Call 239] routeset 5/13: +24 rows (total 4624) -> bus_data_current_chicago.csv
# [Call 240] routeset 6/13: +15 rows (total 4639) -> bus_data_current_chicago.csv
# [Call 241] routeset 7/13: +31 rows (total 4670) -> bus_data_current_chicago.csv
# [Call 242] routeset 8/13: +38 rows (total 4708) -> bus_data_current_chicago.csv
# [Call 243] routeset 9/13: +11 rows (total 4719) -> bus_data_current_chicago.csv
# [Call 244] routeset 10/13: +3 rows (total 4722) -> bus_data_current_chicago.csv
# [Call 245] routeset 11/13: +2 rows (total 4724) -> bus_data_current_chicago.csv
# [Call 246] routeset 12/13: +10 rows (total 4734) -> bus_data_current_chicago.csv
# [Call 247] routeset 13/13: +0 rows (total 4734) -> bus_data_current_chicago.csv
# --- Sweep 19 complete. Sleeping 30s ---
# --- Sweep 20 @ 2026-02-20 00:12:07 CST ---
# [Call 248] routeset 1/13: +30 rows (total 4764) -> bus_data_current_chicago.csv
# [Call 249] routeset 2/13: +25 rows (total 4789) -> bus_data_current_chicago.csv
# [Call 250] routeset 3/13: +21 rows (total 4810) -> bus_data_current_chicago.csv
# [Call 251] routeset 4/13: +17 rows (total 4827) -> bus_data_current_chicago.csv
# [Call 252] routeset 5/13: +23 rows (total 4850) -> bus_data_current_chicago.csv
# [Call 253] routeset 6/13: +15 rows (total 4865) -> bus_data_current_chicago.csv
# [Call 254] routeset 7/13: +31 rows (total 4896) -> bus_data_current_chicago.csv
# [Call 255] routeset 8/13: +37 rows (total 4933) -> bus_data_current_chicago.csv
# [Call 256] routeset 9/13: +11 rows (total 4944) -> bus_data_current_chicago.csv
# [Call 257] routeset 10/13: +3 rows (total 4947) -> bus_data_current_chicago.csv
# [Call 258] routeset 11/13: +2 rows (total 4949) -> bus_data_current_chicago.csv
# [Call 259] routeset 12/13: +10 rows (total 4959) -> bus_data_current_chicago.csv
# [Call 260] routeset 13/13: +0 rows (total 4959) -> bus_data_current_chicago.csv
# --- Sweep 20 complete. Sleeping 30s ---
# --- Sweep 21 @ 2026-02-20 00:13:43 CST ---
# [Call 261] routeset 1/13: +29 rows (total 4988) -> bus_data_current_chicago.csv
# [Call 262] routeset 2/13: +25 rows (total 5013) -> bus_data_current_chicago.csv
# [Call 263] routeset 3/13: +22 rows (total 5035) -> bus_data_current_chicago.csv
# [Call 264] routeset 4/13: +16 rows (total 5051) -> bus_data_current_chicago.csv
# [Call 265] routeset 5/13: +22 rows (total 5073) -> bus_data_current_chicago.csv
# [Call 266] routeset 6/13: +15 rows (total 5088) -> bus_data_current_chicago.csv
# [Call 267] routeset 7/13: +31 rows (total 5119) -> bus_data_current_chicago.csv
# [Call 268] routeset 8/13: +37 rows (total 5156) -> bus_data_current_chicago.csv
# [Call 269] routeset 9/13: +10 rows (total 5166) -> bus_data_current_chicago.csv
# [Call 270] routeset 10/13: +3 rows (total 5169) -> bus_data_current_chicago.csv
# [Call 271] routeset 11/13: +2 rows (total 5171) -> bus_data_current_chicago.csv
# [Call 272] routeset 12/13: +10 rows (total 5181) -> bus_data_current_chicago.csv
# [Call 273] routeset 13/13: +0 rows (total 5181) -> bus_data_current_chicago.csv
# --- Sweep 21 complete. Sleeping 30s ---
# --- Sweep 22 @ 2026-02-20 00:15:19 CST ---
# [Call 274] routeset 1/13: +29 rows (total 5210) -> bus_data_current_chicago.csv
# [Call 275] routeset 2/13: +25 rows (total 5235) -> bus_data_current_chicago.csv
# [Call 276] routeset 3/13: +22 rows (total 5257) -> bus_data_current_chicago.csv
# [Call 277] routeset 4/13: +16 rows (total 5273) -> bus_data_current_chicago.csv
# [Call 278] routeset 5/13: +21 rows (total 5294) -> bus_data_current_chicago.csv
# [Call 279] routeset 6/13: +14 rows (total 5308) -> bus_data_current_chicago.csv
# [Call 280] routeset 7/13: +30 rows (total 5338) -> bus_data_current_chicago.csv
# [Call 281] routeset 8/13: +35 rows (total 5373) -> bus_data_current_chicago.csv
# [Call 282] routeset 9/13: +10 rows (total 5383) -> bus_data_current_chicago.csv
# [Call 283] routeset 10/13: +3 rows (total 5386) -> bus_data_current_chicago.csv
# [Call 284] routeset 11/13: +2 rows (total 5388) -> bus_data_current_chicago.csv
# [Call 285] routeset 12/13: +10 rows (total 5398) -> bus_data_current_chicago.csv
# [Call 286] routeset 13/13: +0 rows (total 5398) -> bus_data_current_chicago.csv
# --- Sweep 22 complete. Sleeping 30s ---
# --- Sweep 23 @ 2026-02-20 00:16:55 CST ---
# [Call 287] routeset 1/13: +30 rows (total 5428) -> bus_data_current_chicago.csv
# [Call 288] routeset 2/13: +25 rows (total 5453) -> bus_data_current_chicago.csv
# [Call 289] routeset 3/13: +20 rows (total 5473) -> bus_data_current_chicago.csv
# [Call 290] routeset 4/13: +16 rows (total 5489) -> bus_data_current_chicago.csv
# [Call 291] routeset 5/13: +22 rows (total 5511) -> bus_data_current_chicago.csv
# [Call 292] routeset 6/13: +15 rows (total 5526) -> bus_data_current_chicago.csv
# [Call 293] routeset 7/13: +29 rows (total 5555) -> bus_data_current_chicago.csv
# [Call 294] routeset 8/13: +35 rows (total 5590) -> bus_data_current_chicago.csv
# [Call 295] routeset 9/13: +10 rows (total 5600) -> bus_data_current_chicago.csv
# [Call 296] routeset 10/13: +3 rows (total 5603) -> bus_data_current_chicago.csv
# [Call 297] routeset 11/13: +2 rows (total 5605) -> bus_data_current_chicago.csv
# [Call 298] routeset 12/13: +10 rows (total 5615) -> bus_data_current_chicago.csv
# [Call 299] routeset 13/13: +0 rows (total 5615) -> bus_data_current_chicago.csv
# --- Sweep 23 complete. Sleeping 30s ---
# --- Sweep 24 @ 2026-02-20 00:18:30 CST ---
# [Call 300] routeset 1/13: +29 rows (total 5644) -> bus_data_current_chicago.csv
# [Call 301] routeset 2/13: +26 rows (total 5670) -> bus_data_current_chicago.csv
# [Call 302] routeset 3/13: +19 rows (total 5689) -> bus_data_current_chicago.csv
# [Call 303] routeset 4/13: +16 rows (total 5705) -> bus_data_current_chicago.csv
# [Call 304] routeset 5/13: +21 rows (total 5726) -> bus_data_current_chicago.csv
# [Call 305] routeset 6/13: +15 rows (total 5741) -> bus_data_current_chicago.csv
# [Call 306] routeset 7/13: +29 rows (total 5770) -> bus_data_current_chicago.csv
# [Call 307] routeset 8/13: +35 rows (total 5805) -> bus_data_current_chicago.csv
# [Call 308] routeset 9/13: +10 rows (total 5815) -> bus_data_current_chicago.csv
# [Call 309] routeset 10/13: +3 rows (total 5818) -> bus_data_current_chicago.csv
# [Call 310] routeset 11/13: +2 rows (total 5820) -> bus_data_current_chicago.csv
# [Call 311] routeset 12/13: +9 rows (total 5829) -> bus_data_current_chicago.csv
# [Call 312] routeset 13/13: +0 rows (total 5829) -> bus_data_current_chicago.csv
# --- Sweep 24 complete. Sleeping 30s ---
# --- Sweep 25 @ 2026-02-20 00:20:06 CST ---
# [Call 313] routeset 1/13: +29 rows (total 5858) -> bus_data_current_chicago.csv
# [Call 314] routeset 2/13: +26 rows (total 5884) -> bus_data_current_chicago.csv
# [Call 315] routeset 3/13: +19 rows (total 5903) -> bus_data_current_chicago.csv
# [Call 316] routeset 4/13: +13 rows (total 5916) -> bus_data_current_chicago.csv
# [Call 317] routeset 5/13: +21 rows (total 5937) -> bus_data_current_chicago.csv
# [Call 318] routeset 6/13: +16 rows (total 5953) -> bus_data_current_chicago.csv
# [Call 319] routeset 7/13: +28 rows (total 5981) -> bus_data_current_chicago.csv
# [Call 320] routeset 8/13: +35 rows (total 6016) -> bus_data_current_chicago.csv
# [Call 321] routeset 9/13: +9 rows (total 6025) -> bus_data_current_chicago.csv
# [Call 322] routeset 10/13: +3 rows (total 6028) -> bus_data_current_chicago.csv
# [Call 323] routeset 11/13: +2 rows (total 6030) -> bus_data_current_chicago.csv
# [Call 324] routeset 12/13: +9 rows (total 6039) -> bus_data_current_chicago.csv
# [Call 325] routeset 13/13: +0 rows (total 6039) -> bus_data_current_chicago.csv
# --- Sweep 25 complete. Sleeping 30s ---
# --- Sweep 26 @ 2026-02-20 00:21:42 CST ---
# [Call 326] routeset 1/13: +29 rows (total 6068) -> bus_data_current_chicago.csv
# [Call 327] routeset 2/13: +25 rows (total 6093) -> bus_data_current_chicago.csv
# [Call 328] routeset 3/13: +20 rows (total 6113) -> bus_data_current_chicago.csv
# [Call 329] routeset 4/13: +12 rows (total 6125) -> bus_data_current_chicago.csv
# [Call 330] routeset 5/13: +21 rows (total 6146) -> bus_data_current_chicago.csv
# [Call 331] routeset 6/13: +15 rows (total 6161) -> bus_data_current_chicago.csv
# [Call 332] routeset 7/13: +28 rows (total 6189) -> bus_data_current_chicago.csv
# [Call 333] routeset 8/13: +35 rows (total 6224) -> bus_data_current_chicago.csv
# [Call 334] routeset 9/13: +9 rows (total 6233) -> bus_data_current_chicago.csv
# [Call 335] routeset 10/13: +3 rows (total 6236) -> bus_data_current_chicago.csv
# [Call 336] routeset 11/13: +1 rows (total 6237) -> bus_data_current_chicago.csv
# [Call 337] routeset 12/13: +8 rows (total 6245) -> bus_data_current_chicago.csv
# [Call 338] routeset 13/13: +0 rows (total 6245) -> bus_data_current_chicago.csv
# --- Sweep 26 complete. Sleeping 30s ---
# --- Sweep 27 @ 2026-02-20 00:23:18 CST ---
# [Call 339] routeset 1/13: +27 rows (total 6272) -> bus_data_current_chicago.csv
# [Call 340] routeset 2/13: +25 rows (total 6297) -> bus_data_current_chicago.csv
# [Call 341] routeset 3/13: +20 rows (total 6317) -> bus_data_current_chicago.csv
# [Call 342] routeset 4/13: +14 rows (total 6331) -> bus_data_current_chicago.csv
# [Call 343] routeset 5/13: +22 rows (total 6353) -> bus_data_current_chicago.csv
# [Call 344] routeset 6/13: +14 rows (total 6367) -> bus_data_current_chicago.csv
# [Call 345] routeset 7/13: +28 rows (total 6395) -> bus_data_current_chicago.csv
# [Call 346] routeset 8/13: +34 rows (total 6429) -> bus_data_current_chicago.csv
# [Call 347] routeset 9/13: +9 rows (total 6438) -> bus_data_current_chicago.csv
# [Call 348] routeset 10/13: +3 rows (total 6441) -> bus_data_current_chicago.csv
# [Call 349] routeset 11/13: +0 rows (total 6441) -> bus_data_current_chicago.csv
# [Call 350] routeset 12/13: +8 rows (total 6449) -> bus_data_current_chicago.csv
# [Call 351] routeset 13/13: +0 rows (total 6449) -> bus_data_current_chicago.csv
# --- Sweep 27 complete. Sleeping 30s ---
# --- Sweep 28 @ 2026-02-20 00:24:54 CST ---
# [Call 352] routeset 1/13: +28 rows (total 6477) -> bus_data_current_chicago.csv
# [Call 353] routeset 2/13: +25 rows (total 6502) -> bus_data_current_chicago.csv
# [Call 354] routeset 3/13: +20 rows (total 6522) -> bus_data_current_chicago.csv
# [Call 355] routeset 4/13: +14 rows (total 6536) -> bus_data_current_chicago.csv
# [Call 356] routeset 5/13: +22 rows (total 6558) -> bus_data_current_chicago.csv
# [Call 357] routeset 6/13: +14 rows (total 6572) -> bus_data_current_chicago.csv
# [Call 358] routeset 7/13: +28 rows (total 6600) -> bus_data_current_chicago.csv
# [Call 359] routeset 8/13: +34 rows (total 6634) -> bus_data_current_chicago.csv
# [Call 360] routeset 9/13: +9 rows (total 6643) -> bus_data_current_chicago.csv
# [Call 361] routeset 10/13: +3 rows (total 6646) -> bus_data_current_chicago.csv
# [Call 362] routeset 11/13: +0 rows (total 6646) -> bus_data_current_chicago.csv
# [Call 363] routeset 12/13: +8 rows (total 6654) -> bus_data_current_chicago.csv
# [Call 364] routeset 13/13: +0 rows (total 6654) -> bus_data_current_chicago.csv
# --- Sweep 28 complete. Sleeping 30s ---
# --- Sweep 29 @ 2026-02-20 00:26:30 CST ---
# [Call 365] routeset 1/13: +28 rows (total 6682) -> bus_data_current_chicago.csv
# [Call 366] routeset 2/13: +25 rows (total 6707) -> bus_data_current_chicago.csv
# [Call 367] routeset 3/13: +19 rows (total 6726) -> bus_data_current_chicago.csv
# [Call 368] routeset 4/13: +15 rows (total 6741) -> bus_data_current_chicago.csv
# [Call 369] routeset 5/13: +20 rows (total 6761) -> bus_data_current_chicago.csv
# [Call 370] routeset 6/13: +14 rows (total 6775) -> bus_data_current_chicago.csv
# [Call 371] routeset 7/13: +28 rows (total 6803) -> bus_data_current_chicago.csv
# [Call 372] routeset 8/13: +33 rows (total 6836) -> bus_data_current_chicago.csv
# [Call 373] routeset 9/13: +8 rows (total 6844) -> bus_data_current_chicago.csv
# [Call 374] routeset 10/13: +3 rows (total 6847) -> bus_data_current_chicago.csv
# [Call 375] routeset 11/13: +0 rows (total 6847) -> bus_data_current_chicago.csv
# [Call 376] routeset 12/13: +8 rows (total 6855) -> bus_data_current_chicago.csv
# [Call 377] routeset 13/13: +0 rows (total 6855) -> bus_data_current_chicago.csv
# --- Sweep 29 complete. Sleeping 30s ---
# --- Sweep 30 @ 2026-02-20 00:28:06 CST ---
# [Call 378] routeset 1/13: +28 rows (total 6883) -> bus_data_current_chicago.csv
# [Call 379] routeset 2/13: +25 rows (total 6908) -> bus_data_current_chicago.csv
# [Call 380] routeset 3/13: +18 rows (total 6926) -> bus_data_current_chicago.csv
# [Call 381] routeset 4/13: +14 rows (total 6940) -> bus_data_current_chicago.csv
# [Call 382] routeset 5/13: +20 rows (total 6960) -> bus_data_current_chicago.csv
# [Call 383] routeset 6/13: +14 rows (total 6974) -> bus_data_current_chicago.csv
# [Call 384] routeset 7/13: +25 rows (total 6999) -> bus_data_current_chicago.csv
# [Call 385] routeset 8/13: +32 rows (total 7031) -> bus_data_current_chicago.csv
# [Call 386] routeset 9/13: +7 rows (total 7038) -> bus_data_current_chicago.csv
# [Call 387] routeset 10/13: +3 rows (total 7041) -> bus_data_current_chicago.csv
# [Call 388] routeset 11/13: +0 rows (total 7041) -> bus_data_current_chicago.csv
# [Call 389] routeset 12/13: +8 rows (total 7049) -> bus_data_current_chicago.csv
# [Call 390] routeset 13/13: +0 rows (total 7049) -> bus_data_current_chicago.csv
# --- Sweep 30 complete. Sleeping 30s ---
# --- Sweep 31 @ 2026-02-20 00:29:42 CST ---
# [Call 391] routeset 1/13: +26 rows (total 7075) -> bus_data_current_chicago.csv
# [Call 392] routeset 2/13: +25 rows (total 7100) -> bus_data_current_chicago.csv
# [Call 393] routeset 3/13: +18 rows (total 7118) -> bus_data_current_chicago.csv
# [Call 394] routeset 4/13: +14 rows (total 7132) -> bus_data_current_chicago.csv
# [Call 395] routeset 5/13: +19 rows (total 7151) -> bus_data_current_chicago.csv
# [Call 396] routeset 6/13: +13 rows (total 7164) -> bus_data_current_chicago.csv
# [Call 397] routeset 7/13: +25 rows (total 7189) -> bus_data_current_chicago.csv
# [Call 398] routeset 8/13: +32 rows (total 7221) -> bus_data_current_chicago.csv
# [Call 399] routeset 9/13: +7 rows (total 7228) -> bus_data_current_chicago.csv
# [Call 400] routeset 10/13: +3 rows (total 7231) -> bus_data_current_chicago.csv
# [Call 401] routeset 11/13: +0 rows (total 7231) -> bus_data_current_chicago.csv
# [Call 402] routeset 12/13: +8 rows (total 7239) -> bus_data_current_chicago.csv
# [Call 403] routeset 13/13: +0 rows (total 7239) -> bus_data_current_chicago.csv
# --- Sweep 31 complete. Sleeping 30s ---
# --- Sweep 32 @ 2026-02-20 00:31:18 CST ---
# [Call 404] routeset 1/13: +24 rows (total 7263) -> bus_data_current_chicago.csv
# [Call 405] routeset 2/13: +23 rows (total 7286) -> bus_data_current_chicago.csv
# [Call 406] routeset 3/13: +17 rows (total 7303) -> bus_data_current_chicago.csv
# [Call 407] routeset 4/13: +14 rows (total 7317) -> bus_data_current_chicago.csv
# [Call 408] routeset 5/13: +20 rows (total 7337) -> bus_data_current_chicago.csv
# [Call 409] routeset 6/13: +13 rows (total 7350) -> bus_data_current_chicago.csv
# [Call 410] routeset 7/13: +23 rows (total 7373) -> bus_data_current_chicago.csv
# [Call 411] routeset 8/13: +32 rows (total 7405) -> bus_data_current_chicago.csv
# [Call 412] routeset 9/13: +8 rows (total 7413) -> bus_data_current_chicago.csv
# [Call 413] routeset 10/13: +3 rows (total 7416) -> bus_data_current_chicago.csv
# [Call 414] routeset 11/13: +0 rows (total 7416) -> bus_data_current_chicago.csv
# [Call 415] routeset 12/13: +8 rows (total 7424) -> bus_data_current_chicago.csv
# [Call 416] routeset 13/13: +0 rows (total 7424) -> bus_data_current_chicago.csv
# --- Sweep 32 complete. Sleeping 30s ---
# --- Sweep 33 @ 2026-02-20 00:32:54 CST ---
# [Call 417] routeset 1/13: +26 rows (total 7450) -> bus_data_current_chicago.csv
# [Call 418] routeset 2/13: +22 rows (total 7472) -> bus_data_current_chicago.csv
# [Call 419] routeset 3/13: +18 rows (total 7490) -> bus_data_current_chicago.csv
# [Call 420] routeset 4/13: +14 rows (total 7504) -> bus_data_current_chicago.csv
# [Call 421] routeset 5/13: +19 rows (total 7523) -> bus_data_current_chicago.csv
# [Call 422] routeset 6/13: +13 rows (total 7536) -> bus_data_current_chicago.csv
# [Call 423] routeset 7/13: +24 rows (total 7560) -> bus_data_current_chicago.csv
# [Call 424] routeset 8/13: +31 rows (total 7591) -> bus_data_current_chicago.csv
# [Call 425] routeset 9/13: +6 rows (total 7597) -> bus_data_current_chicago.csv
# [Call 426] routeset 10/13: +3 rows (total 7600) -> bus_data_current_chicago.csv
# [Call 427] routeset 11/13: +0 rows (total 7600) -> bus_data_current_chicago.csv
# [Call 428] routeset 12/13: +8 rows (total 7608) -> bus_data_current_chicago.csv
# [Call 429] routeset 13/13: +0 rows (total 7608) -> bus_data_current_chicago.csv
# --- Sweep 33 complete. Sleeping 30s ---
# --- Sweep 34 @ 2026-02-20 00:34:30 CST ---
# [Call 430] routeset 1/13: +26 rows (total 7634) -> bus_data_current_chicago.csv
# [Call 431] routeset 2/13: +22 rows (total 7656) -> bus_data_current_chicago.csv
# [Call 432] routeset 3/13: +18 rows (total 7674) -> bus_data_current_chicago.csv
# [Call 433] routeset 4/13: +13 rows (total 7687) -> bus_data_current_chicago.csv
# [Call 434] routeset 5/13: +19 rows (total 7706) -> bus_data_current_chicago.csv
# [Call 435] routeset 6/13: +14 rows (total 7720) -> bus_data_current_chicago.csv
# [Call 436] routeset 7/13: +23 rows (total 7743) -> bus_data_current_chicago.csv
# [Call 437] routeset 8/13: +31 rows (total 7774) -> bus_data_current_chicago.csv
# [Call 438] routeset 9/13: +6 rows (total 7780) -> bus_data_current_chicago.csv
# [Call 439] routeset 10/13: +3 rows (total 7783) -> bus_data_current_chicago.csv
# [Call 440] routeset 11/13: +0 rows (total 7783) -> bus_data_current_chicago.csv
# [Call 441] routeset 12/13: +8 rows (total 7791) -> bus_data_current_chicago.csv
# [Call 442] routeset 13/13: +0 rows (total 7791) -> bus_data_current_chicago.csv
# --- Sweep 34 complete. Sleeping 30s ---
# --- Sweep 35 @ 2026-02-20 00:36:06 CST ---
# [Call 443] routeset 1/13: +25 rows (total 7816) -> bus_data_current_chicago.csv
# [Call 444] routeset 2/13: +21 rows (total 7837) -> bus_data_current_chicago.csv
# [Call 445] routeset 3/13: +17 rows (total 7854) -> bus_data_current_chicago.csv
# [Call 446] routeset 4/13: +14 rows (total 7868) -> bus_data_current_chicago.csv
# [Call 447] routeset 5/13: +19 rows (total 7887) -> bus_data_current_chicago.csv
# [Call 448] routeset 6/13: +14 rows (total 7901) -> bus_data_current_chicago.csv
# [Call 449] routeset 7/13: +23 rows (total 7924) -> bus_data_current_chicago.csv
# [Call 450] routeset 8/13: +30 rows (total 7954) -> bus_data_current_chicago.csv
# [Call 451] routeset 9/13: +6 rows (total 7960) -> bus_data_current_chicago.csv
# [Call 452] routeset 10/13: +3 rows (total 7963) -> bus_data_current_chicago.csv
# [Call 453] routeset 11/13: +0 rows (total 7963) -> bus_data_current_chicago.csv
# [Call 454] routeset 12/13: +7 rows (total 7970) -> bus_data_current_chicago.csv
# [Call 455] routeset 13/13: +0 rows (total 7970) -> bus_data_current_chicago.csv
# --- Sweep 35 complete. Sleeping 30s ---
# --- Sweep 36 @ 2026-02-20 00:37:42 CST ---
# [Call 456] routeset 1/13: +25 rows (total 7995) -> bus_data_current_chicago.csv
# [Call 457] routeset 2/13: +20 rows (total 8015) -> bus_data_current_chicago.csv
# [Call 458] routeset 3/13: +17 rows (total 8032) -> bus_data_current_chicago.csv
# [Call 459] routeset 4/13: +12 rows (total 8044) -> bus_data_current_chicago.csv
# [Call 460] routeset 5/13: +19 rows (total 8063) -> bus_data_current_chicago.csv
# [Call 461] routeset 6/13: +14 rows (total 8077) -> bus_data_current_chicago.csv
# [Call 462] routeset 7/13: +23 rows (total 8100) -> bus_data_current_chicago.csv
# [Call 463] routeset 8/13: +30 rows (total 8130) -> bus_data_current_chicago.csv
# [Call 464] routeset 9/13: +6 rows (total 8136) -> bus_data_current_chicago.csv
# [Call 465] routeset 10/13: +3 rows (total 8139) -> bus_data_current_chicago.csv
# [Call 466] routeset 11/13: +0 rows (total 8139) -> bus_data_current_chicago.csv
# [Call 467] routeset 12/13: +7 rows (total 8146) -> bus_data_current_chicago.csv
# [Call 468] routeset 13/13: +0 rows (total 8146) -> bus_data_current_chicago.csv
# --- Sweep 36 complete. Sleeping 30s ---
# --- Sweep 37 @ 2026-02-20 00:39:18 CST ---
# [Call 469] routeset 1/13: +25 rows (total 8171) -> bus_data_current_chicago.csv
# [Call 470] routeset 2/13: +20 rows (total 8191) -> bus_data_current_chicago.csv
# [Call 471] routeset 3/13: +17 rows (total 8208) -> bus_data_current_chicago.csv
# [Call 472] routeset 4/13: +11 rows (total 8219) -> bus_data_current_chicago.csv
# [Call 473] routeset 5/13: +19 rows (total 8238) -> bus_data_current_chicago.csv
# [Call 474] routeset 6/13: +13 rows (total 8251) -> bus_data_current_chicago.csv
# [Call 475] routeset 7/13: +23 rows (total 8274) -> bus_data_current_chicago.csv
# [Call 476] routeset 8/13: +30 rows (total 8304) -> bus_data_current_chicago.csv
# [Call 477] routeset 9/13: +6 rows (total 8310) -> bus_data_current_chicago.csv
# [Call 478] routeset 10/13: +3 rows (total 8313) -> bus_data_current_chicago.csv
# [Call 479] routeset 11/13: +0 rows (total 8313) -> bus_data_current_chicago.csv
# [Call 480] routeset 12/13: +7 rows (total 8320) -> bus_data_current_chicago.csv
# [Call 481] routeset 13/13: +0 rows (total 8320) -> bus_data_current_chicago.csv
# --- Sweep 37 complete. Sleeping 30s ---
# --- Sweep 38 @ 2026-02-20 00:40:54 CST ---
# [Call 482] routeset 1/13: +24 rows (total 8344) -> bus_data_current_chicago.csv
# [Call 483] routeset 2/13: +21 rows (total 8365) -> bus_data_current_chicago.csv
# [Call 484] routeset 3/13: +17 rows (total 8382) -> bus_data_current_chicago.csv
# [Call 485] routeset 4/13: +12 rows (total 8394) -> bus_data_current_chicago.csv
# [Call 486] routeset 5/13: +18 rows (total 8412) -> bus_data_current_chicago.csv
# [Call 487] routeset 6/13: +13 rows (total 8425) -> bus_data_current_chicago.csv
# [Call 488] routeset 7/13: +23 rows (total 8448) -> bus_data_current_chicago.csv
# [Call 489] routeset 8/13: +30 rows (total 8478) -> bus_data_current_chicago.csv
# [Call 490] routeset 9/13: +6 rows (total 8484) -> bus_data_current_chicago.csv
# [Call 491] routeset 10/13: +3 rows (total 8487) -> bus_data_current_chicago.csv
# [Call 492] routeset 11/13: +0 rows (total 8487) -> bus_data_current_chicago.csv
# [Call 493] routeset 12/13: +7 rows (total 8494) -> bus_data_current_chicago.csv
# [Call 494] routeset 13/13: +0 rows (total 8494) -> bus_data_current_chicago.csv
# --- Sweep 38 complete. Sleeping 30s ---
# --- Sweep 39 @ 2026-02-20 00:42:30 CST ---
# [Call 495] routeset 1/13: +24 rows (total 8518) -> bus_data_current_chicago.csv
# [Call 496] routeset 2/13: +21 rows (total 8539) -> bus_data_current_chicago.csv
# [Call 497] routeset 3/13: +17 rows (total 8556) -> bus_data_current_chicago.csv
# [Call 498] routeset 4/13: +14 rows (total 8570) -> bus_data_current_chicago.csv
# [Call 499] routeset 5/13: +18 rows (total 8588) -> bus_data_current_chicago.csv
# [Call 500] routeset 6/13: +13 rows (total 8601) -> bus_data_current_chicago.csv
# [Call 501] routeset 7/13: +22 rows (total 8623) -> bus_data_current_chicago.csv
# [Call 502] routeset 8/13: +29 rows (total 8652) -> bus_data_current_chicago.csv
# [Call 503] routeset 9/13: +6 rows (total 8658) -> bus_data_current_chicago.csv
# [Call 504] routeset 10/13: +3 rows (total 8661) -> bus_data_current_chicago.csv
# [Call 505] routeset 11/13: +0 rows (total 8661) -> bus_data_current_chicago.csv
# [Call 506] routeset 12/13: +7 rows (total 8668) -> bus_data_current_chicago.csv
# [Call 507] routeset 13/13: +0 rows (total 8668) -> bus_data_current_chicago.csv
# --- Sweep 39 complete. Sleeping 30s ---
# --- Sweep 40 @ 2026-02-20 00:44:06 CST ---
# [Call 508] routeset 1/13: +24 rows (total 8692) -> bus_data_current_chicago.csv
# [Call 509] routeset 2/13: +20 rows (total 8712) -> bus_data_current_chicago.csv
# [Call 510] routeset 3/13: +17 rows (total 8729) -> bus_data_current_chicago.csv
# [Call 511] routeset 4/13: +14 rows (total 8743) -> bus_data_current_chicago.csv
# [Call 512] routeset 5/13: +18 rows (total 8761) -> bus_data_current_chicago.csv
# [Call 513] routeset 6/13: +12 rows (total 8773) -> bus_data_current_chicago.csv
# [Call 514] routeset 7/13: +22 rows (total 8795) -> bus_data_current_chicago.csv
# [Call 515] routeset 8/13: +29 rows (total 8824) -> bus_data_current_chicago.csv
# [Call 516] routeset 9/13: +6 rows (total 8830) -> bus_data_current_chicago.csv
# [Call 517] routeset 10/13: +3 rows (total 8833) -> bus_data_current_chicago.csv
# [Call 518] routeset 11/13: +0 rows (total 8833) -> bus_data_current_chicago.csv
# [Call 519] routeset 12/13: +7 rows (total 8840) -> bus_data_current_chicago.csv
# [Call 520] routeset 13/13: +0 rows (total 8840) -> bus_data_current_chicago.csv
# --- Sweep 40 complete. Sleeping 30s ---
# --- Sweep 41 @ 2026-02-20 00:45:42 CST ---
# [Call 521] routeset 1/13: +23 rows (total 8863) -> bus_data_current_chicago.csv
# [Call 522] routeset 2/13: +20 rows (total 8883) -> bus_data_current_chicago.csv
# [Call 523] routeset 3/13: +15 rows (total 8898) -> bus_data_current_chicago.csv
# [Call 524] routeset 4/13: +14 rows (total 8912) -> bus_data_current_chicago.csv
# [Call 525] routeset 5/13: +18 rows (total 8930) -> bus_data_current_chicago.csv
# [Call 526] routeset 6/13: +12 rows (total 8942) -> bus_data_current_chicago.csv
# [Call 527] routeset 7/13: +22 rows (total 8964) -> bus_data_current_chicago.csv
# [Call 528] routeset 8/13: +29 rows (total 8993) -> bus_data_current_chicago.csv
# [Call 529] routeset 9/13: +6 rows (total 8999) -> bus_data_current_chicago.csv
# [Call 530] routeset 10/13: +3 rows (total 9002) -> bus_data_current_chicago.csv
# [Call 531] routeset 11/13: +0 rows (total 9002) -> bus_data_current_chicago.csv
# [Call 532] routeset 12/13: +7 rows (total 9009) -> bus_data_current_chicago.csv
# [Call 533] routeset 13/13: +0 rows (total 9009) -> bus_data_current_chicago.csv
# --- Sweep 41 complete. Sleeping 30s ---
# --- Sweep 42 @ 2026-02-20 00:47:18 CST ---
# [Call 534] routeset 1/13: +23 rows (total 9032) -> bus_data_current_chicago.csv
# [Call 535] routeset 2/13: +20 rows (total 9052) -> bus_data_current_chicago.csv
# [Call 536] routeset 3/13: +16 rows (total 9068) -> bus_data_current_chicago.csv
# [Call 537] routeset 4/13: +14 rows (total 9082) -> bus_data_current_chicago.csv
# [Call 538] routeset 5/13: +19 rows (total 9101) -> bus_data_current_chicago.csv
# [Call 539] routeset 6/13: +13 rows (total 9114) -> bus_data_current_chicago.csv
# [Call 540] routeset 7/13: +21 rows (total 9135) -> bus_data_current_chicago.csv
# [Call 541] routeset 8/13: +27 rows (total 9162) -> bus_data_current_chicago.csv
# [Call 542] routeset 9/13: +6 rows (total 9168) -> bus_data_current_chicago.csv
# [Call 543] routeset 10/13: +3 rows (total 9171) -> bus_data_current_chicago.csv
# [Call 544] routeset 11/13: +0 rows (total 9171) -> bus_data_current_chicago.csv
# [Call 545] routeset 12/13: +7 rows (total 9178) -> bus_data_current_chicago.csv
# [Call 546] routeset 13/13: +0 rows (total 9178) -> bus_data_current_chicago.csv
# --- Sweep 42 complete. Sleeping 30s ---
# --- Sweep 43 @ 2026-02-20 00:48:54 CST ---
# [Call 547] routeset 1/13: +21 rows (total 9199) -> bus_data_current_chicago.csv
# [Call 548] routeset 2/13: +20 rows (total 9219) -> bus_data_current_chicago.csv
# [Call 549] routeset 3/13: +15 rows (total 9234) -> bus_data_current_chicago.csv
# [Call 550] routeset 4/13: +14 rows (total 9248) -> bus_data_current_chicago.csv
# [Call 551] routeset 5/13: +18 rows (total 9266) -> bus_data_current_chicago.csv
# ...
# [Call 5228] routeset 2/13: +96 rows (total 224649) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5229] routeset 3/13: +78 rows (total 224727) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5230] routeset 4/13: +70 rows (total 224797) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5231] routeset 5/13: +79 rows (total 224876) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5232] routeset 6/13: +72 rows (total 224948) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5233] routeset 7/13: +105 rows (total 225053) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5234] routeset 8/13: +100 rows (total 225153) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5235] routeset 9/13: +68 rows (total 225221) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5236] routeset 10/13: +33 rows (total 225254) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5237] routeset 11/13: +21 rows (total 225275) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5238] routeset 12/13: +57 rows (total 225332) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5239] routeset 13/13: +8 rows (total 225340) -> bus_data_current_chicago.csv
# --- Sweep 403 complete. Sleeping 30s ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# --- Sweep 404 @ 2026-02-20 10:35:11 CST ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5240] routeset 1/13: +89 rows (total 225429) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5241] routeset 2/13: +95 rows (total 225524) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5242] routeset 3/13: +74 rows (total 225598) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5243] routeset 4/13: +69 rows (total 225667) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5244] routeset 5/13: +78 rows (total 225745) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5245] routeset 6/13: +73 rows (total 225818) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5246] routeset 7/13: +106 rows (total 225924) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5247] routeset 8/13: +100 rows (total 226024) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5248] routeset 9/13: +69 rows (total 226093) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5249] routeset 10/13: +34 rows (total 226127) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5250] routeset 11/13: +20 rows (total 226147) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5251] routeset 12/13: +57 rows (total 226204) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5252] routeset 13/13: +8 rows (total 226212) -> bus_data_current_chicago.csv
# --- Sweep 404 complete. Sleeping 30s ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# --- Sweep 405 @ 2026-02-20 10:36:50 CST ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5253] routeset 1/13: +89 rows (total 226301) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5254] routeset 2/13: +95 rows (total 226396) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5255] routeset 3/13: +76 rows (total 226472) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5256] routeset 4/13: +68 rows (total 226540) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5257] routeset 5/13: +78 rows (total 226618) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5258] routeset 6/13: +70 rows (total 226688) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5259] routeset 7/13: +105 rows (total 226793) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5260] routeset 8/13: +102 rows (total 226895) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5261] routeset 9/13: +70 rows (total 226965) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5262] routeset 10/13: +34 rows (total 226999) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5263] routeset 11/13: +20 rows (total 227019) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5264] routeset 12/13: +56 rows (total 227075) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5265] routeset 13/13: +8 rows (total 227083) -> bus_data_current_chicago.csv
# --- Sweep 405 complete. Sleeping 30s ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# --- Sweep 406 @ 2026-02-20 10:38:29 CST ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5266] routeset 1/13: +89 rows (total 227172) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5267] routeset 2/13: +96 rows (total 227268) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5268] routeset 3/13: +76 rows (total 227344) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5269] routeset 4/13: +70 rows (total 227414) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5270] routeset 5/13: +79 rows (total 227493) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5271] routeset 6/13: +72 rows (total 227565) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5272] routeset 7/13: +106 rows (total 227671) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5273] routeset 8/13: +100 rows (total 227771) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5274] routeset 9/13: +70 rows (total 227841) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5275] routeset 10/13: +34 rows (total 227875) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5276] routeset 11/13: +21 rows (total 227896) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5277] routeset 12/13: +55 rows (total 227951) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5278] routeset 13/13: +7 rows (total 227958) -> bus_data_current_chicago.csv
# --- Sweep 406 complete. Sleeping 30s ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# --- Sweep 407 @ 2026-02-20 10:40:08 CST ---
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5279] routeset 1/13: +89 rows (total 228047) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5280] routeset 2/13: +93 rows (total 228140) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5281] routeset 3/13: +76 rows (total 228216) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5282] routeset 4/13: +69 rows (total 228285) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5283] routeset 5/13: +79 rows (total 228364) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5284] routeset 6/13: +73 rows (total 228437) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5285] routeset 7/13: +106 rows (total 228543) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5286] routeset 8/13: +100 rows (total 228643) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5287] routeset 9/13: +68 rows (total 228711) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5288] routeset 10/13: +34 rows (total 228745) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5289] routeset 11/13: +22 rows (total 228767) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5290] routeset 12/13: +53 rows (total 228820) -> bus_data_current_chicago.csv
#   [S3] upload ERROR (continuing with same local file): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
# [Call 5291] routeset 13/13: +8 rows (total 228828) -> bus_data_current_chicago.csv
#   [S3] upload ERROR on exit (file kept): Your session has expired or credentials have changed. Please reauthenticate using 'aws login'.
#
# Done. Sweeps: 407, calls: 5291, total rows written: 228828
